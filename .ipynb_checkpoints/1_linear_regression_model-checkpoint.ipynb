# %% [markdown]
# # A mystery case of a Linear Regression
# We get a function and learn to infer W and b.
#
# **Things we'll (always) need**
# 1. input data
# 2. inference graph
# 3. training graph (define _loss_ and _optimizer_)
# 4. run the graph

# %%
# 1.1 Import tensorflow and other libraries.
import tensorflow as tf
import numpy as np

# %matplotlib inline
import pylab

# %%
# 1.2 Create input data using NumPy. y = x * 0.1 + 0.3 + noise
x_data = np.random.rand(100).astype(np.float32)
noise = np.random.normal(scale=0.01, size=len(x_data))
y_data = x_data * 0.1 + 0.3 + noise

# Uncomment the following line to plot our input data.
pylab.plot(x_data, y_data, '.')

# %%
# 1.3 Buld inference graph.
# Create Variables W and b that compute y_data = W * x_data + b
W = tf.Variable(tf.random_uniform([1], 0.0, 1.0), name="weight")
b = tf.Variable(tf.zeros([1]), name="bias")
y = W * x_data + b

# Uncomment the following lines to see W and b are.
print(W.name)
print(b.name)
# Out:
# weight:0
# bias:0

# %%
# 1.4 Build training graph.

### THE ULTIMATE GOAL: to minimize my loss

loss = tf.reduce_mean(tf.square(y - y_data))  # Create an operation that calculates loss.
optimizer = tf.train.GradientDescentOptimizer(0.5)  # Create an optimizer.
train = optimizer.minimize(loss)  # Create an operation that minimizes loss.
init = tf.initialize_all_variables()  # Create an operation initializes all the variables.

# Uncomment the following 3 lines to see what 'loss', 'optimizer' and 'train' are.
print("loss:", loss)
print("optimizer:", optimizer)
print("train:", train)
print(init)
# Out:
# loss: Tensor("Mean_1:0", shape=(), dtype=float32)
# optimizer: <tensorflow.python.training.gradient_descent.GradientDescentOptimizer object at 0x1146ca860>
# train: name: "GradientDescent_1"
# op: "NoOp"
# input: "^GradientDescent_1/update_weight/ApplyGradientDescent"
# input: "^GradientDescent_1/update_bias/ApplyGradientDescent"
#
# name: "init_1"
# op: "NoOp"
# input: "^Variable/Assign"
# input: "^Variable_1/Assign"
# input: "^Variable_2/Assign"
# input: "^Variable_3/Assign"
# input: "^weight/Assign"
# input: "^bias/Assign"

# %%
# 1.5 Uncomment the following line to see what we have built.
print(tf.get_default_graph().as_graph_def())
# Out:
# node {
#   name: "random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# ...

# %% [markdown]
# ^ this is my Neural Network. It seems. What does it mean? Dunno.

# %%
# 1.6 Create a session and launch the graph.
sess = tf.Session()
sess.run(init)
y_initial_values = sess.run(y)  # Save initial values for plotting later.

# Uncomment the following line to see the initial W and b values.
print(sess.run([W, b]))
# Out:
# [array([ 0.96233428], dtype=float32), array([ 0.], dtype=float32)]

# %%
# 1.7 Perform training.
for step in range(201):
    sess.run(train)
    # Uncomment the following two lines to watch training happen real time.
    if step % 20 == 0:
        print(step, sess.run([W, b]))

print(sess.run([W, b]))
# Out:
# 0 [array([ 0.80241895], dtype=float32), array([-0.17233853], dtype=float32)]
# 20 [array([ 0.32124719], dtype=float32), array([ 0.17020479], dtype=float32)]
# 40 [array([ 0.16737525], dtype=float32), array([ 0.25937799], dtype=float32)]
# 60 [array([ 0.1208413], dtype=float32), array([ 0.28634575], dtype=float32)]
# 80 [array([ 0.10676856], dtype=float32), array([ 0.2945013], dtype=float32)]
# 100 [array([ 0.10251266], dtype=float32), array([ 0.29696772], dtype=float32)]
# 120 [array([ 0.10122558], dtype=float32), array([ 0.29771361], dtype=float32)]
# 140 [array([ 0.10083635], dtype=float32), array([ 0.29793918], dtype=float32)]
# 160 [array([ 0.10071863], dtype=float32), array([ 0.2980074], dtype=float32)]
# 180 [array([ 0.10068306], dtype=float32), array([ 0.29802802], dtype=float32)]
# 200 [array([ 0.10067227], dtype=float32), array([ 0.29803428], dtype=float32)]
# [array([ 0.10067227], dtype=float32), array([ 0.29803428], dtype=float32)]

# %%
# 1.8 Uncomment the following lines to compare.

pylab.plot(x_data, y_data, '.', label="target_values")
pylab.plot(x_data, y_initial_values, ".", label="initial_values")
pylab.plot(x_data, sess.run(y), ".", label="trained_values")
pylab.legend()
pylab.ylim(0, 1.0)
# Out:
# (0, 1.0)

# %% [markdown]
# ^
# 1. the inital values are those that we randomly initialized before commencing the learning.
# 2. the target values are those that constitute the solution graph and
# 3. the trained values are those that we found by machine learning. yay.

# %% [markdown]
# <p>Next to [2_mnist.ipynb](2_mnist.ipynb).</p>
